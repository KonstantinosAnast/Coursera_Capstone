# %%
# !pip install geocoder

import pandas as pd
import numpy as np
import geocoder
# Out:
# ...
# ERROR: Error checking for conflicts.
# Traceback (most recent call last):
#   File "/Users/konstantinosanastasiadis/opt/anaconda3/lib/python3.7/site-packages/pip/_vendor/pkg_resources/__init__.py", line 3021, in _dep_map
#     return self.__dep_map
#   File "/Users/konstantinosanastasiadis/opt/anaconda3/lib/python3.7/site-packages/pip/_vendor/pkg_resources/__init__.py", line 2815, in __getattr__
#     raise AttributeError(attr)
# AttributeError: _DistInfoDistribution__dep_map
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/konstantinosanastasiadis/opt/anaconda3/lib/python3.7/site-packages/pip/_vendor/pkg_resources/__init__.py", line 3012, in _parsed_pkg_info
#     return self._pkg_info
#   File "/Users/konstantinosanastasiadis/opt/anaconda3/lib/python3.7/site-packages/pip/_vendor/pkg_resources/__init__.py", line 2815, in __getattr__
#     raise AttributeError(attr)
# AttributeError: _pkg_info
#
# ...

# %%
df = pd.read_csv('ny-neighborhoods.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 Postal Code           Borough  \
# 0           0         M3A        North York
# 1           1         M4A        North York
# 2           2         M5A  Downtown Toronto
# 3           3         M6A        North York
# 4           4         M7A  Downtown Toronto
#
#                                   Neighborhood
# 0                                    Parkwoods
# 1                             Victoria Village
# 2                    Regent Park, Harbourfront
# 3             Lawrence Manor, Lawrence Heights
# 4  Queen's Park, Ontario Provincial Government

# %%
lat_lng_toronto = pd.read_csv('Geospatial_Coordinates.csv')
lat_lng_toronto.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
latitude = []
longitude = []
poco = lat_lng_toronto['Postal Code']
    
for p_code in df['Postal Code']:
    here = poco[poco == p_code].index[0]
    latitude.append(lat_lng_toronto['Latitude'].iloc[here])
    longitude.append(lat_lng_toronto['Longitude'].iloc[here])
    
df['Latitude'], df['Longitude'] = latitude, longitude
df.head(10)
# Out:
#    Unnamed: 0 Postal Code           Borough  \
# 0           0         M3A        North York
# 1           1         M4A        North York
# 2           2         M5A  Downtown Toronto
# 3           3         M6A        North York
# 4           4         M7A  Downtown Toronto
# 5           5         M9A         Etobicoke
# 6           6         M1B       Scarborough
# 7           7         M3B        North York
# 8           8         M4B         East York
# 9           9         M5B  Downtown Toronto
#
#                                   Neighborhood   Latitude  Longitude
# 0                                    Parkwoods  43.753259 -79.329656
# 1                             Victoria Village  43.725882 -79.315572
# 2                    Regent Park, Harbourfront  43.654260 -79.360636
# 3             Lawrence Manor, Lawrence Heights  43.718518 -79.464763
# 4  Queen's Park, Ontario Provincial Government  43.662301 -79.389494
# ...

# %%
df.to_csv('toronto-neighborhoods_latlng.csv')
